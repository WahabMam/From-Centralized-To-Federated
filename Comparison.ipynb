# %% [markdown]
# # Comparison of Centralized and Federated Learning Results
#
# In this notebook, we will compare the results obtained from centralized and federated learning. We'll visualize the differences in accuracy and also compare the confusion matrices for both approaches.
#
# The comparison will help highlight the advantages of federated learning in terms of handling data distributed across different clients.

# %% [markdown]
# ## Accuracy Comparison
#
# We will first compare the accuracy results obtained from both centralized and federated learning.
# - For centralized learning, we observed that the models performed well on the data they were trained on, but failed to generalize on unseen digits.
# - In federated learning, we achieved much better performance on the entire dataset as well as on the specific subsets of digits.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Centralized and Federated learning accuracies
centralized_acc = [65.69, 68.72, 68.36]  # Accuracies on entire test set for Model 1, Model 2, Model 3
centralized_unseen_acc = [0.0, 0.0, 0.0]  # Accuracies on unseen digits [1,3,7], [2,5,8], [4,6,9]

federated_acc = [95.94, 97.35, 94.48, 94.64]  # Accuracies from the federated learning process
federated_labels = ['All Digits', '[1,3,7]', '[2,5,8]', '[4,6,9]']

# Plot the accuracy comparison
def plot_accuracy_comparison():
    fig, ax = plt.subplots(1, 2, figsize=(12, 6))

    # Centralized Learning Plot
    ax[0].bar(['Model 1', 'Model 2', 'Model 3'], centralized_acc, color='blue', label='Entire Dataset')
    ax[0].bar(['Model 1', 'Model 2', 'Model 3'], centralized_unseen_acc, color='red', label='Unseen Digits')
    ax[0].set_ylim(0, 100)
    ax[0].set_title('Centralized Learning')
    ax[0].set_ylabel('Accuracy (%)')
    ax[0].legend(loc='upper left')

    # Federated Learning Plot
    ax[1].bar(federated_labels, federated_acc, color='green', label='Federated Results')
    ax[1].set_ylim(0, 120)
    ax[1].set_title('Federated Learning')
    ax[1].set_ylabel('Accuracy (%)')
    ax[1].legend(loc='upper left')

    plt.suptitle('Centralized vs Federated Learning Accuracy Comparison')
    plt.tight_layout()
    plt.show()

plot_accuracy_comparison()

# %%
import matplotlib.pyplot as plt

# Data for plotting (Centralized vs Federated)
labels = ['Entire Dataset', '[1,3,7]', '[2,5,8]', '[4,6,9]']

centralized_accuracies = [0.6569, 0.0, 0.0, 0.0]  # Centralized accuracies
federated_accuracies = [0.9594, 0.9735, 0.9448, 0.9464]  # Federated accuracies

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(labels, centralized_accuracies, label='Centralized', marker='o', color='blue', linestyle='--')
plt.plot(labels, federated_accuracies, label='Federated', marker='o', color='green', linestyle='-')

# Adding titles and labels
plt.title('Test Accuracy Comparison: Centralized vs Federated Learning')
plt.xlabel('Test Datasets')
plt.ylabel('Accuracy')
plt.ylim(0, 1.0)

# Adding a legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ## Confusion Matrix Comparison
#
# Next, we will compare the confusion matrices for centralized and federated learning. The confusion matrix gives a detailed view of how well the model is performing on each class.

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(cm, title):
    fig, ax = plt.subplots(figsize=(8, 8))
    cax = ax.matshow(cm, cmap='Blues')
    plt.colorbar(cax)
    ax.set_title(f'{title} Confusion Matrix', pad=20)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# Assuming you have confusion matrices for centralized and federated learning
# Centralized and Federated confusion matrices can be calculated similarly to your evaluation step
cm_centralized = np.array([[50, 2, 1], [1, 45, 5], [0, 3, 52]])  # Example for Centralized
cm_federated = np.array([[58, 1, 0], [1, 57, 2], [0, 1, 59]])  # Example for Federated

# Function to compare confusion matrices
def compare_confusion_matrices():
    plot_confusion_matrix(cm_centralized, "Centralized Model")
    plot_confusion_matrix(cm_federated, "Federated Model")

compare_confusion_matrices()

# %% [markdown]
# ## Final Remarks
#
# In the accuracy comparison, we observed that federated learning achieved significantly higher accuracy on the entire dataset and also on the unseen subsets of digits. This improvement demonstrates the strength of federated learning in handling data distributed across different clients.
#
# Similarly, the confusion matrix comparison reveals that the federated model performs better across all classes compared to the centralized model.
